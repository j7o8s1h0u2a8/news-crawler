# %%
# !pip install -U textblob
# Out:
# Requirement already up-to-date: textblob in e:\anaconda3\lib\site-packages
# Requirement already up-to-date: nltk>=3.1 in e:\anaconda3\lib\site-packages (from textblob)
# Requirement already up-to-date: six in e:\anaconda3\lib\site-packages (from nltk>=3.1->textblob)

# %%
import nltk
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package biocreative_ppi to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package biocreative_ppi is already up-to-date!
# [nltk_data]    | Downloading package brown to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package brown_tei to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown_tei is already up-to-date!
# [nltk_data]    | Downloading package cess_cat to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cess_cat is already up-to-date!
# [nltk_data]    | Downloading package cess_esp to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\cess_esp.zip.
# [nltk_data]    | Downloading package chat80 to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\chat80.zip.
# [nltk_data]    | Downloading package city_database to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\city_database.zip.
# [nltk_data]    | Downloading package cmudict to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\cmudict.zip.
# [nltk_data]    | Downloading package comparative_sentences to
# [nltk_data]    |     C:\Users\BIG DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\comparative_sentences.zip.
# [nltk_data]    | Downloading package comtrans to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package conll2000 to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\conll2002.zip.
# [nltk_data]    | Downloading package conll2007 to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package crubadan to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\crubadan.zip.
# [nltk_data]    | Downloading package dependency_treebank to
# [nltk_data]    |     C:\Users\BIG DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\dependency_treebank.zip.
# [nltk_data]    | Downloading package dolch to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package europarl_raw to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\europarl_raw.zip.
# [nltk_data]    | Downloading package floresta to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\floresta.zip.
# [nltk_data]    | Downloading package framenet_v15 to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\framenet_v15.zip.
# [nltk_data]    | Downloading package framenet_v17 to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\framenet_v17.zip.
# [nltk_data]    | Downloading package gazetteers to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\gazetteers.zip.
# [nltk_data]    | Downloading package genesis to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\genesis.zip.
# [nltk_data]    | Downloading package gutenberg to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\gutenberg.zip.
# [nltk_data]    | Downloading package ieer to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ieer.zip.
# [nltk_data]    | Downloading package inaugural to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\inaugural.zip.
# [nltk_data]    | Downloading package indian to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\indian.zip.
# [nltk_data]    | Downloading package jeita to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package kimmo to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\kimmo.zip.
# [nltk_data]    | Downloading package knbc to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package lin_thesaurus to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\lin_thesaurus.zip.
# [nltk_data]    | Downloading package mac_morpho to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\mac_morpho.zip.
# [nltk_data]    | Downloading package machado to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package masc_tagged to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package moses_sample to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\moses_sample.zip.
# [nltk_data]    | Downloading package movie_reviews to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\movie_reviews.zip.
# [nltk_data]    | Downloading package names to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\names.zip.
# [nltk_data]    | Downloading package nombank.1.0 to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package nps_chat to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\nps_chat.zip.
# [nltk_data]    | Downloading package omw to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\omw.zip.
# [nltk_data]    | Downloading package opinion_lexicon to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\opinion_lexicon.zip.
# [nltk_data]    | Downloading package paradigms to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\paradigms.zip.
# [nltk_data]    | Downloading package pil to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pil.zip.
# [nltk_data]    | Downloading package pl196x to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pl196x.zip.
# [nltk_data]    | Downloading package ppattach to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ppattach.zip.
# [nltk_data]    | Downloading package problem_reports to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\problem_reports.zip.
# [nltk_data]    | Downloading package propbank to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package ptb to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ptb.zip.
# [nltk_data]    | Downloading package product_reviews_1 to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\product_reviews_1.zip.
# [nltk_data]    | Downloading package product_reviews_2 to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\product_reviews_2.zip.
# [nltk_data]    | Downloading package pros_cons to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\pros_cons.zip.
# [nltk_data]    | Downloading package qc to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\qc.zip.
# [nltk_data]    | Downloading package reuters to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package rte to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\rte.zip.
# [nltk_data]    | Downloading package semcor to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package senseval to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\senseval.zip.
# [nltk_data]    | Downloading package sentiwordnet to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\sentiwordnet.zip.
# [nltk_data]    | Downloading package sentence_polarity to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\sentence_polarity.zip.
# [nltk_data]    | Downloading package shakespeare to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\shakespeare.zip.
# [nltk_data]    | Downloading package sinica_treebank to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\sinica_treebank.zip.
# [nltk_data]    | Downloading package smultron to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\smultron.zip.
# [nltk_data]    | Downloading package state_union to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\state_union.zip.
# [nltk_data]    | Downloading package stopwords to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\stopwords.zip.
# [nltk_data]    | Downloading package subjectivity to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\subjectivity.zip.
# [nltk_data]    | Downloading package swadesh to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\swadesh.zip.
# [nltk_data]    | Downloading package switchboard to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\switchboard.zip.
# [nltk_data]    | Downloading package timit to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\timit.zip.
# [nltk_data]    | Downloading package toolbox to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\toolbox.zip.
# [nltk_data]    | Downloading package treebank to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\treebank.zip.
# [nltk_data]    | Downloading package twitter_samples to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\twitter_samples.zip.
# [nltk_data]    | Downloading package udhr to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\udhr.zip.
# [nltk_data]    | Downloading package udhr2 to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\udhr2.zip.
# [nltk_data]    | Downloading package unicode_samples to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\unicode_samples.zip.
# [nltk_data]    | Downloading package universal_treebanks_v20 to
# [nltk_data]    |     C:\Users\BIG DATA\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package verbnet to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\verbnet.zip.
# [nltk_data]    | Downloading package webtext to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\webtext.zip.
# [nltk_data]    | Downloading package wordnet to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\wordnet.zip.
# [nltk_data]    | Downloading package wordnet_ic to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\wordnet_ic.zip.
# [nltk_data]    | Downloading package words to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\words.zip.
# [nltk_data]    | Downloading package ycoe to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\ycoe.zip.
# [nltk_data]    | Downloading package rslp to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping stemmers\rslp.zip.
# [nltk_data]    | Downloading package hmm_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\BIG DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\hmm_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package maxent_treebank_pos_tagger to
# [nltk_data]    |     C:\Users\BIG DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\maxent_treebank_pos_tagger.zip.
# [nltk_data]    | Downloading package universal_tagset to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\universal_tagset.zip.
# [nltk_data]    | Downloading package maxent_ne_chunker to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping chunkers\maxent_ne_chunker.zip.
# [nltk_data]    | Downloading package punkt to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping tokenizers\punkt.zip.
# [nltk_data]    | Downloading package book_grammars to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\book_grammars.zip.
# [nltk_data]    | Downloading package sample_grammars to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\sample_grammars.zip.
# [nltk_data]    | Downloading package spanish_grammars to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\spanish_grammars.zip.
# [nltk_data]    | Downloading package basque_grammars to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\basque_grammars.zip.
# [nltk_data]    | Downloading package large_grammars to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping grammars\large_grammars.zip.
# [nltk_data]    | Downloading package tagsets to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping help\tagsets.zip.
# [nltk_data]    | Downloading package snowball_data to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package bllip_wsj_no_aux to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\bllip_wsj_no_aux.zip.
# [nltk_data]    | Downloading package word2vec_sample to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping models\word2vec_sample.zip.
# [nltk_data]    | Downloading package panlex_swadesh to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    | Downloading package mte_teip5 to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\mte_teip5.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     C:\Users\BIG DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package panlex_lite to C:\Users\BIG
# [nltk_data]    |     DATA\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\panlex_lite.zip.
# [nltk_data]    | Error with downloaded zip file
# False

# %%
from textblob import TextBlob
import nltk.data

# %%
wiki = TextBlob("Python is a high-level, general-purpose programming language.")

# %%
wiki.tags
# Out:
# [('Python', 'NNP'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('high-level', 'JJ'),
#  ('general-purpose', 'JJ'),
#  ('programming', 'NN'),
#  ('language', 'NN')]
